# %%
import os
import sys
from clahe3 import doClahe as doClahe1
from clahe4 import doClahe as doClahe2
import numpy as np
import matplotlib.pyplot as plt
import cv2
np.set_printoptions(threshold=sys.maxsize)

# %%
block=4
x = cv2.imread("/Users/srie/Documents/Upwork/Scott/Fingerprint_binary/finger_8x8.png")
rs1 = x.shape[0]-x.shape[0]%block
rs2 = x.shape[1]-x.shape[1]%block
x = cv2.resize(x, (rs2,rs1))
# print(x)
x = cv2.cvtColor(x, cv2.COLOR_RGBA2RGB)
x = cv2.cvtColor(x, cv2.COLOR_RGB2HLS)
# x = cv2.cvtColor(x, cv2.COLOR_BGR2HLS)
# print(x)
h, l, s = cv2.split(x)
print(l.shape)
# x = np.random.randint(low=0, high=255, size=(224,224))
# l = np.array([135, 121, 106, 100, 143, 133, 111, 101, 136, 107, 126, 145, 26, 100, 155, 157])
# l = np.reshape(l, (4,4))
clahe, converted = doClahe1(l, block)
print("Source")
print(np.ravel(l).tolist())
print("Clahe")
print(np.ravel(clahe).tolist())
print("Converted")
print(np.ravel(converted).tolist())
# Out:
# (8, 8)
# 128 128 128 128
# 255 255 64 64
# 255 255 128 128
# 191 191 128 128
# 255 255 255 255
# 128 128 255 255
# 0 0 191 191
# 128 128 128 128
# Stats(min, max, sum, mean)
# 0 255 57 96.703125
# Source
# [88, 80, 72, 66, 62, 54, 46, 43, 119, 116, 110, 104, 100, 106, 105, 102, 120, 118, 129, 150, 160, 141, 126, 120, 162, 187, 202, 198, 193, 153, 113, 135, 206, 193, 167, 141, 126, 96, 95, 144, 117, 108, 108, 92, 81, 90, 133, 170, 74, 74, 68, 81, 106, 122, 141, 168, 41, 78, 96, 97, 102, 118, 131, 143]
# Converted
# [128, 80, 72, 66, 62, 54, 46, 43, 255, 116, 110, 104, 100, 106, 105, 102, 191, 118, 129, 150, 160, 141, 126, 120, 191, 187, 202, 198, 193, 153, 113, 135, 255, 193, 167, 141, 126, 96, 95, 144, 128, 108, 108, 92, 81, 90, 133, 170, 95, 74, 68, 81, 106, 122, 141, 168, 128, 78, 96, 97, 102, 118, 131, 143]

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,3,1)
plt.imshow(l, cmap='gray')

plt.subplot(1,3,2)
plt.imshow(clahe, cmap='gray')


plt.subplot(1,3,3)
plt.imshow(converted, cmap='gray')

# %%
clahe, converted = doClahe2(l, block)
plt.figure(figsize=(20,10))
plt.subplot(1,3,1)
plt.imshow(l, cmap='gray')

plt.subplot(1,3,2)
plt.imshow(clahe, cmap='gray')


plt.subplot(1,3,3)
plt.imshow(converted, cmap='gray')
# Out:
# 0 0 0 0
# 0 0 255 255
# 0 0 255 255
# 255 255 0 0
# 128 128 0 0
# 255 255 0 0
# 128 128 255 255
# 255 255 255 255
# Stats(min, max, sum, mean)
# 0 255 60 107.203125
